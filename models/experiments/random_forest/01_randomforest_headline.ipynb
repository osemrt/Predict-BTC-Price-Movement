# %% [markdown]
# ## Importing the Dataset

# %%
import pandas as pd

# %%
dataset_path = '../../dataset/'

# %%
df_news = pd.read_csv(dataset_path + '/news/news [only_date].csv')
df_price = pd.read_csv(dataset_path + '/price/btc_usd_daily.csv')

# %%
df_news.head()
# Out:
#          date                                           headline  \
# 0  2020-03-16  Bitcoin Risks Falling to $2,900 if Market is H...
# 1  2020-03-16  Here’s Why Bitcoin Didn’t Bottom at $3,800 Acc...
# 2  2020-03-16  Bitcoin Sinks to $4,390 as Dow’s 1,000-Point D...
# 3  2020-03-16  Bitcoin could soon be in the museum of illusio...
# 4  2020-03-16  Bitcoin Price Analysis: BTC’s 3-Day Consolidat...
#
#                                               source
# 0  https://www.newsbtc.com/2020/03/14/bitcoin-ris...
# 1  https://www.newsbtc.com/2020/03/15/heres-why-b...
# 2  https://www.newsbtc.com/2020/03/16/bitcoin-sin...
# 3  https://eng.ambcrypto.com/bitcoin-could-soon-b...
# 4  https://cryptopotato.com/bitcoin-price-analysi...

# %%
df_news.shape
# Out:
# (17047, 3)

# %%
df_price.head()
# Out:
#          date     open    close     high      low  change       volume  \
# 0  2020-03-24  6436.64  6734.80  6789.02  6411.07    4.63  48221910672
# 1  2020-03-23  5831.37  6416.31  6443.93  5785.00   10.03  46491916000
# 2  2020-03-22  6185.56  5830.25  6359.70  5823.71   -5.74  40099664740
# 3  2020-03-21  6206.52  6185.07  6378.14  5932.82   -0.35  42494390880
# 4  2020-03-20  6191.65  6198.78  6844.26  5865.78    0.12  54442976103
#
#      market_cap
# 0  123148917787
# 1  117314776187
# 2  106591196069
# 3  113068192795
# 4  113309245860

# %%
df_price.shape
# Out:
# (2522, 8)

# %% [markdown]
# ## Data cleaning and preprocessing

# %%
# Grouping the news according to date
date_index = df_news.groupby(['date']).groups
keys = list(date_index.keys())

dict = {}

for key in keys:
    titles = df_news[df_news['date'] == key]['headline']
    titles = titles.values.tolist()
    dict[key] = titles
    
df_grouped_news = pd.DataFrame(list(dict.values()))
df_grouped_news.insert(0, "date", keys)
df_grouped_news.head()
# Out:
#          date                                                  0  \
# 0  2017-01-01  Colombia Declares Bitcoin and Other Digital Cu...
# 1  2017-01-02  Bitspark's George Harrap lists his takeaways f...
# 2  2017-01-03  State Street bank is on the verge of putting s...
# 3  2017-01-04  Charlie Shrem is re-imagining investment on th...
# 4  2017-01-05  Need a catch-up on recent price developments? ...
#
#                                                    1  \
# 0                    Bitcoin Consolidation Continues
# 1  Do 2016's political changes foreshadow blockch...
# 2  Market intelligence firm Greenwich Associates ...
# 3  Kraken announced 3rd January that it had becom...
# 4        China Intervenes Yuan Soars Bitcoin Crashes
#
#                                                    2  \
# 0  The price of bitcoin passed $1,000 during the ...
# 1  Republic of Georgia to Introduce Blockchain Pl...
# 2  India's fifth-largest bank has built a blockch...
# 3  The price of bitcoin is now just $110 short of...
# 4  Iranian Banker: Bitcoin is Changing Banking; C...
#
#                                                    3  \
# 0  The New Year Could Bode Well for Bitcoin and B...
# 1       Can Cryptocoins Be Environmentally Friendly?
# 2  Argentinian bitcoin startup Ripio has raised $...
# 3  PwC's Ajit Tripathi gives CoinDesk his predict...
# 4                     FinTech in Nigeria Set to Grow
#
#                                                    4  \
# 0                   Bitcoin Starts 2017 at the $1000
# 1  Mexico’s Largest Bank Acquires Fintech Payment...
# 2  What's in store for Delaware's blockchain work...
# 3  2016 was a quiet one for blockchain regulation...
# 4  Hyperledger Blockchain Project Announces ‘Tech...
#
#                                                    5  \
# 0  The European Union Wants to Identify Bitcoin U...
# 1               Will Bitcoin Reach an All-Time High?
# 2  Spanish banking group BBVA has released a new ...
# 3  One of the UAE's largest telcos has announced ...
# 4  Argentine Bitcoin Wallet BitPagos Raises $1.9 ...
#
#                                                    6  \
# 0                                               None
# 1  Vitalik Buterin: Bitcoin More Likely Than Ethe...
# 2  Financial Times Writer Says Bitcoin is Worth “...
# 3  The SEC has delayed its decision on the Winkle...
# 4  Newsflash: Bitcoin Price Takes a Steep Fall Be...
#
#                                                    7  \
# 0                                               None
# 1  How Blockchain Technology Can Improve the Airl...
# 2                     Bitcoin Has Hit a Price Target
# 3  Bitcoin prices surged 4th January, surpassing ...
# 4  CoinDesk contributor Willy Woo presents an in-...
#
#                                                    8  ...    32    33    34  \
# 0                                               None  ...  None  None  None
# 1      Bitcoin Price is Trading Beyond $1000 in 2017  ...  None  None  None
# 2  Dutch and Korean Mainstream Media Extensively ...  ...  None  None  None
# 3  Bitcoin prices have shot past the $1,100 mark ...  ...  None  None  None
# 4   Bitcoin Rally Was Starting to Feel Unsustainable  ...  None  None  None
#
#      35    36    37    38    39    40    41
# 0  None  None  None  None  None  None  None
# 1  None  None  None  None  None  None  None
# 2  None  None  None  None  None  None  None
# 3  None  None  None  None  None  None  None
# 4  None  None  None  None  None  None  None
#
# [5 rows x 43 columns]

# %%
df_grouped_news.shape
# Out:
# (1128, 43)

# %%
# Change the date format of dataframes
df_price['date'] = pd.to_datetime(df_price['date'])
df_grouped_news['date'] = pd.to_datetime(df_grouped_news['date'])

# %%
combined_data = pd.merge(df_grouped_news, df_price, on='date', how='inner')
combined_data.head()
# Out:
#         date                                                  0  \
# 0 2017-01-01  Colombia Declares Bitcoin and Other Digital Cu...
# 1 2017-01-02  Bitspark's George Harrap lists his takeaways f...
# 2 2017-01-03  State Street bank is on the verge of putting s...
# 3 2017-01-04  Charlie Shrem is re-imagining investment on th...
# 4 2017-01-05  Need a catch-up on recent price developments? ...
#
#                                                    1  \
# 0                    Bitcoin Consolidation Continues
# 1  Do 2016's political changes foreshadow blockch...
# 2  Market intelligence firm Greenwich Associates ...
# 3  Kraken announced 3rd January that it had becom...
# 4        China Intervenes Yuan Soars Bitcoin Crashes
#
#                                                    2  \
# 0  The price of bitcoin passed $1,000 during the ...
# 1  Republic of Georgia to Introduce Blockchain Pl...
# 2  India's fifth-largest bank has built a blockch...
# 3  The price of bitcoin is now just $110 short of...
# 4  Iranian Banker: Bitcoin is Changing Banking; C...
#
#                                                    3  \
# 0  The New Year Could Bode Well for Bitcoin and B...
# 1       Can Cryptocoins Be Environmentally Friendly?
# 2  Argentinian bitcoin startup Ripio has raised $...
# 3  PwC's Ajit Tripathi gives CoinDesk his predict...
# 4                     FinTech in Nigeria Set to Grow
#
#                                                    4  \
# 0                   Bitcoin Starts 2017 at the $1000
# 1  Mexico’s Largest Bank Acquires Fintech Payment...
# 2  What's in store for Delaware's blockchain work...
# 3  2016 was a quiet one for blockchain regulation...
# 4  Hyperledger Blockchain Project Announces ‘Tech...
#
#                                                    5  \
# 0  The European Union Wants to Identify Bitcoin U...
# 1               Will Bitcoin Reach an All-Time High?
# 2  Spanish banking group BBVA has released a new ...
# 3  One of the UAE's largest telcos has announced ...
# 4  Argentine Bitcoin Wallet BitPagos Raises $1.9 ...
#
#                                                    6  \
# 0                                               None
# 1  Vitalik Buterin: Bitcoin More Likely Than Ethe...
# 2  Financial Times Writer Says Bitcoin is Worth “...
# 3  The SEC has delayed its decision on the Winkle...
# 4  Newsflash: Bitcoin Price Takes a Steep Fall Be...
#
#                                                    7  \
# 0                                               None
# 1  How Blockchain Technology Can Improve the Airl...
# 2                     Bitcoin Has Hit a Price Target
# 3  Bitcoin prices surged 4th January, surpassing ...
# 4  CoinDesk contributor Willy Woo presents an in-...
#
#                                                    8  ...    39    40    41  \
# 0                                               None  ...  None  None  None
# 1      Bitcoin Price is Trading Beyond $1000 in 2017  ...  None  None  None
# 2  Dutch and Korean Mainstream Media Extensively ...  ...  None  None  None
# 3  Bitcoin prices have shot past the $1,100 mark ...  ...  None  None  None
# 4   Bitcoin Rally Was Starting to Feel Unsustainable  ...  None  None  None
#
#       open    close     high      low change     volume   market_cap
# 0   963.66   998.33  1003.08   958.70   3.60  147775008  16050407461
# 1   998.62  1021.75  1031.39   996.70   2.32  222184992  16429024775
# 2  1021.60  1043.84  1044.08  1021.60   2.18  185168000  16786368910
# 3  1044.40  1154.73  1159.42  1044.40  10.56  344945984  18571869009
# 4  1156.73  1013.38  1191.10   910.42 -12.39  510199008  16300254795
#
# [5 rows x 50 columns]

# %%
# Adding labels to the news
label = combined_data['change'].apply(lambda x: 1 if x>0 else 0)
combined_data['label'] = label
combined_data.head()
# Out:
#         date                                                  0  \
# 0 2017-01-01  Colombia Declares Bitcoin and Other Digital Cu...
# 1 2017-01-02  Bitspark's George Harrap lists his takeaways f...
# 2 2017-01-03  State Street bank is on the verge of putting s...
# 3 2017-01-04  Charlie Shrem is re-imagining investment on th...
# 4 2017-01-05  Need a catch-up on recent price developments? ...
#
#                                                    1  \
# 0                    Bitcoin Consolidation Continues
# 1  Do 2016's political changes foreshadow blockch...
# 2  Market intelligence firm Greenwich Associates ...
# 3  Kraken announced 3rd January that it had becom...
# 4        China Intervenes Yuan Soars Bitcoin Crashes
#
#                                                    2  \
# 0  The price of bitcoin passed $1,000 during the ...
# 1  Republic of Georgia to Introduce Blockchain Pl...
# 2  India's fifth-largest bank has built a blockch...
# 3  The price of bitcoin is now just $110 short of...
# 4  Iranian Banker: Bitcoin is Changing Banking; C...
#
#                                                    3  \
# 0  The New Year Could Bode Well for Bitcoin and B...
# 1       Can Cryptocoins Be Environmentally Friendly?
# 2  Argentinian bitcoin startup Ripio has raised $...
# 3  PwC's Ajit Tripathi gives CoinDesk his predict...
# 4                     FinTech in Nigeria Set to Grow
#
#                                                    4  \
# 0                   Bitcoin Starts 2017 at the $1000
# 1  Mexico’s Largest Bank Acquires Fintech Payment...
# 2  What's in store for Delaware's blockchain work...
# 3  2016 was a quiet one for blockchain regulation...
# 4  Hyperledger Blockchain Project Announces ‘Tech...
#
#                                                    5  \
# 0  The European Union Wants to Identify Bitcoin U...
# 1               Will Bitcoin Reach an All-Time High?
# 2  Spanish banking group BBVA has released a new ...
# 3  One of the UAE's largest telcos has announced ...
# 4  Argentine Bitcoin Wallet BitPagos Raises $1.9 ...
#
#                                                    6  \
# 0                                               None
# 1  Vitalik Buterin: Bitcoin More Likely Than Ethe...
# 2  Financial Times Writer Says Bitcoin is Worth “...
# 3  The SEC has delayed its decision on the Winkle...
# 4  Newsflash: Bitcoin Price Takes a Steep Fall Be...
#
#                                                    7  \
# 0                                               None
# 1  How Blockchain Technology Can Improve the Airl...
# 2                     Bitcoin Has Hit a Price Target
# 3  Bitcoin prices surged 4th January, surpassing ...
# 4  CoinDesk contributor Willy Woo presents an in-...
#
#                                                    8  ...    40    41  \
# 0                                               None  ...  None  None
# 1      Bitcoin Price is Trading Beyond $1000 in 2017  ...  None  None
# 2  Dutch and Korean Mainstream Media Extensively ...  ...  None  None
# 3  Bitcoin prices have shot past the $1,100 mark ...  ...  None  None
# 4   Bitcoin Rally Was Starting to Feel Unsustainable  ...  None  None
#
#       open    close     high      low change     volume   market_cap label
# 0   963.66   998.33  1003.08   958.70   3.60  147775008  16050407461     1
# 1   998.62  1021.75  1031.39   996.70   2.32  222184992  16429024775     1
# 2  1021.60  1043.84  1044.08  1021.60   2.18  185168000  16786368910     1
# 3  1044.40  1154.73  1159.42  1044.40  10.56  344945984  18571869009     1
# 4  1156.73  1013.38  1191.10   910.42 -12.39  510199008  16300254795     0
#
# [5 rows x 51 columns]

# %%
combined_data.shape
# Out:
# (1128, 51)

# %%
# Splitting the train and test sets
train = combined_data[combined_data['date'] < '20191201']
test = combined_data[combined_data['date'] > '20191130']

# %%
# Removing punctuations
data = train.iloc[:, 1:24]
data.replace("[^a-zA-Z]", " ", regex=True, inplace=True)
data.head()
# Out:
#                                                   0   \
# 0  Colombia Declares Bitcoin and Other Digital Cu...
# 1  Bitspark s George Harrap lists his takeaways f...
# 2  State Street bank is on the verge of putting s...
# 3  Charlie Shrem is re imagining investment on th...
# 4  Need a catch up on recent price developments  ...
#
#                                                   1   \
# 0                    Bitcoin Consolidation Continues
# 1  Do      s political changes foreshadow blockch...
# 2  Market intelligence firm Greenwich Associates ...
# 3  Kraken announced  rd January that it had becom...
# 4        China Intervenes Yuan Soars Bitcoin Crashes
#
#                                                   2   \
# 0  The price of bitcoin passed        during the ...
# 1  Republic of Georgia to Introduce Blockchain Pl...
# 2  India s fifth largest bank has built a blockch...
# 3  The price of bitcoin is now just      short of...
# 4  Iranian Banker  Bitcoin is Changing Banking  C...
#
#                                                   3   \
# 0  The New Year Could Bode Well for Bitcoin and B...
# 1       Can Cryptocoins Be Environmentally Friendly
# 2  Argentinian bitcoin startup Ripio has raised  ...
# 3  PwC s Ajit Tripathi gives CoinDesk his predict...
# 4                     FinTech in Nigeria Set to Grow
#
#                                                   4   \
# 0                   Bitcoin Starts      at the
# 1  Mexico s Largest Bank Acquires Fintech Payment...
# 2  What s in store for Delaware s blockchain work...
# 3       was a quiet one for blockchain regulation...
# 4  Hyperledger Blockchain Project Announces  Tech...
#
#                                                   5   \
# 0  The European Union Wants to Identify Bitcoin U...
# 1               Will Bitcoin Reach an All Time High
# 2  Spanish banking group BBVA has released a new ...
# 3  One of the UAE s largest telcos has announced ...
# 4  Argentine Bitcoin Wallet BitPagos Raises      ...
#
#                                                   6   \
# 0                                               None
# 1  Vitalik Buterin  Bitcoin More Likely Than Ethe...
# 2  Financial Times Writer Says Bitcoin is Worth  ...
# 3  The SEC has delayed its decision on the Winkle...
# 4  Newsflash  Bitcoin Price Takes a Steep Fall Be...
#
#                                                   7   \
# 0                                               None
# 1  How Blockchain Technology Can Improve the Airl...
# 2                     Bitcoin Has Hit a Price Target
# 3  Bitcoin prices surged  th January  surpassing ...
# 4  CoinDesk contributor Willy Woo presents an in ...
#
#                                                   8   \
# 0                                               None
# 1      Bitcoin Price is Trading Beyond       in
# 2  Dutch and Korean Mainstream Media Extensively ...
# 3  Bitcoin prices have shot past the        mark ...
# 4   Bitcoin Rally Was Starting to Feel Unsustainable
#
#                                                   9   ...  \
# 0                                               None  ...
# 1                                               None  ...
# 2  Scammers in Australia Demand Bitcoin and Gift ...  ...
# 3  Bitcoin Price Blitzes Beyond       Closes in o...  ...
# 4  Hacker Compromises Bitcoin Wallet KeepKey Foun...  ...
#
#                                                   13  \
# 0                                               None
# 1                                               None
# 2  Bitcoin Will Get Native Support in Microsoft E...
# 3         Bitcoin s Market Cap Crosses       Billion
# 4  CoinDesk s Corin Faife recaps how last year sa...
#
#                                                   14  \
# 0                                               None
# 1                                               None
# 2                                               None
# 3  UAE Healthcare Provider to Store Patient Recor...
# 4  Bitcoin prices plunged nearly      in an hour ...
#
#                                                   15  \
# 0                                               None
# 1                                               None
# 2                                               None
# 3          Bitcoin Usage Gains Traction in Indonesia
# 4  Bitcoin exchange Bitstamp s funding campaign h...
#
#                                                   16  \
# 0                                               None
# 1                                               None
# 2                                               None
# 3  Yes Bank Develops Blockchain to Digitize Vendo...
# 4  Industry insiders share their thoughts about a...
#
#                                           17  \
# 0                                       None
# 1                                       None
# 2                                       None
# 3  Bitcoin Makes History Reaches Gold Parity
# 4                                       None
#
#                                                   18  \
# 0                                               None
# 1                                               None
# 2                                               None
# 3  Despite the hype around enterprise blockchain ...
# 4                                               None
#
#                                                   19  \
# 0                                               None
# 1                                               None
# 2                                               None
# 3  Insurance market advisors to the US Treasury D...
# 4                                               None
#
#                                                   20    21    22
# 0                                               None  None  None
# 1                                               None  None  None
# 2                                               None  None  None
# 3  A new bitcoin software update boasts more than...  None  None
# 4                                               None  None  None
#
# [5 rows x 23 columns]

# %%
# Converting titles to lowercase
rows, cols = data.shape
for index in range(0, cols):
    data[index] = data[index].str.lower()
    
data.head()
# Out:
#                                                   0   \
# 0  colombia declares bitcoin and other digital cu...
# 1  bitspark s george harrap lists his takeaways f...
# 2  state street bank is on the verge of putting s...
# 3  charlie shrem is re imagining investment on th...
# 4  need a catch up on recent price developments  ...
#
#                                                   1   \
# 0                    bitcoin consolidation continues
# 1  do      s political changes foreshadow blockch...
# 2  market intelligence firm greenwich associates ...
# 3  kraken announced  rd january that it had becom...
# 4        china intervenes yuan soars bitcoin crashes
#
#                                                   2   \
# 0  the price of bitcoin passed        during the ...
# 1  republic of georgia to introduce blockchain pl...
# 2  india s fifth largest bank has built a blockch...
# 3  the price of bitcoin is now just      short of...
# 4  iranian banker  bitcoin is changing banking  c...
#
#                                                   3   \
# 0  the new year could bode well for bitcoin and b...
# 1       can cryptocoins be environmentally friendly
# 2  argentinian bitcoin startup ripio has raised  ...
# 3  pwc s ajit tripathi gives coindesk his predict...
# 4                     fintech in nigeria set to grow
#
#                                                   4   \
# 0                   bitcoin starts      at the
# 1  mexico s largest bank acquires fintech payment...
# 2  what s in store for delaware s blockchain work...
# 3       was a quiet one for blockchain regulation...
# 4  hyperledger blockchain project announces  tech...
#
#                                                   5   \
# 0  the european union wants to identify bitcoin u...
# 1               will bitcoin reach an all time high
# 2  spanish banking group bbva has released a new ...
# 3  one of the uae s largest telcos has announced ...
# 4  argentine bitcoin wallet bitpagos raises      ...
#
#                                                   6   \
# 0                                               None
# 1  vitalik buterin  bitcoin more likely than ethe...
# 2  financial times writer says bitcoin is worth  ...
# 3  the sec has delayed its decision on the winkle...
# 4  newsflash  bitcoin price takes a steep fall be...
#
#                                                   7   \
# 0                                               None
# 1  how blockchain technology can improve the airl...
# 2                     bitcoin has hit a price target
# 3  bitcoin prices surged  th january  surpassing ...
# 4  coindesk contributor willy woo presents an in ...
#
#                                                   8   \
# 0                                               None
# 1      bitcoin price is trading beyond       in
# 2  dutch and korean mainstream media extensively ...
# 3  bitcoin prices have shot past the        mark ...
# 4   bitcoin rally was starting to feel unsustainable
#
#                                                   9   ...  \
# 0                                               None  ...
# 1                                               None  ...
# 2  scammers in australia demand bitcoin and gift ...  ...
# 3  bitcoin price blitzes beyond       closes in o...  ...
# 4  hacker compromises bitcoin wallet keepkey foun...  ...
#
#                                                   13  \
# 0                                               None
# 1                                               None
# 2  bitcoin will get native support in microsoft e...
# 3         bitcoin s market cap crosses       billion
# 4  coindesk s corin faife recaps how last year sa...
#
#                                                   14  \
# 0                                               None
# 1                                               None
# 2                                               None
# 3  uae healthcare provider to store patient recor...
# 4  bitcoin prices plunged nearly      in an hour ...
#
#                                                   15  \
# 0                                               None
# 1                                               None
# 2                                               None
# 3          bitcoin usage gains traction in indonesia
# 4  bitcoin exchange bitstamp s funding campaign h...
#
#                                                   16  \
# 0                                               None
# 1                                               None
# 2                                               None
# 3  yes bank develops blockchain to digitize vendo...
# 4  industry insiders share their thoughts about a...
#
#                                           17  \
# 0                                       None
# 1                                       None
# 2                                       None
# 3  bitcoin makes history reaches gold parity
# 4                                       None
#
#                                                   18  \
# 0                                               None
# 1                                               None
# 2                                               None
# 3  despite the hype around enterprise blockchain ...
# 4                                               None
#
#                                                   19  \
# 0                                               None
# 1                                               None
# 2                                               None
# 3  insurance market advisors to the us treasury d...
# 4                                               None
#
#                                                   20    21    22
# 0                                               None  None  None
# 1                                               None  None  None
# 2                                               None  None  None
# 3  a new bitcoin software update boasts more than...  None  None
# 4                                               None  None  None
#
# [5 rows x 23 columns]

# %%
titles = []

for row in range(0, rows):
    titles.append(' '.join(str(x) for x in data.iloc[row, 0: cols] if str(x) != 'None'))
    
titles[0]
# Out:
# 'colombia declares bitcoin and other digital currencies illegal bitcoin consolidation continues the price of bitcoin passed        during the first day of trading in       the new year could bode well for bitcoin and blockchains bitcoin starts      at the       the european union wants to identify bitcoin users'

# %% [markdown]
# ## Training model

# %%
from sklearn.feature_extraction.text import CountVectorizer
from sklearn.ensemble import RandomForestClassifier

# %%
# implement Bag of Words
countvector = CountVectorizer(ngram_range=(2, 2))
traindataset = countvector.fit_transform(titles)

# %%
# implement RandomForest Classifier
randomClassifier = RandomForestClassifier(n_estimators=200, criterion='entropy')
randomClassifier.fit(traindataset, train['label'])
# Out:
# RandomForestClassifier(bootstrap=True, ccp_alpha=0.0, class_weight=None,
#                        criterion='entropy', max_depth=None, max_features='auto',
#                        max_leaf_nodes=None, max_samples=None,
#                        min_impurity_decrease=0.0, min_impurity_split=None,
#                        min_samples_leaf=1, min_samples_split=2,
#                        min_weight_fraction_leaf=0.0, n_estimators=200,
#                        n_jobs=None, oob_score=False, random_state=None,
#                        verbose=0, warm_start=False)

# %%
# Predict for test dataset
test_transform = []

for row in range(0, len(test.index)):
    test_transform.append(' '.join(str(x) for x in test.iloc[row, 1:cols] if str(x) != 'None'))
test_dataset = countvector.transform(test_transform)
predictions = randomClassifier.predict(test_dataset)
test_transform[1]
# Out:
# 'Vertcoin 51% Attack ‘Motive Uncertain’ as Hackers Lose up to $4,000 P2P Bitcoin Marketplace Paxful Set to Surpass LocalBitcoins in Volume Binance Crypto Exchange Adds Four Trading Pairs for Russian Ruble Bitcoin’s efficiency improvements are a really big deal: Matt Odell OneCoin Website Goes Offline as Net Closes in on $4B Ponzi Scheme Price Analysis 02/12: BTC, ETH, XRP, BCH, LTC, EOS, BNB, BSV, XLM, TRX Bitcoin Price: Cracking $7.4K Opens Path to $8.1K Resistance — Analyst Binance’s CZ: This Vibrant Country Is One of the Fastest-Growing Crypto Nations Former CFTC Chair to Remain Focused on Crypto and Blockchain at New Law Firm US Stock Markets to Have a Slow 2020, Will Investors Turn to Bitcoin and Crypto? 459 Days Until BTC Hits Its Longest Streak Without a New All-Time High Litecoin-Funded Grin Developer Challenges Mimblewimble’s Privacy Issue Three Reasons Why Fundstrat’s Tom Lee Is Optimistic About Bitcoin’s Price Next Year Analysts Flip Long on Bitcoin After Bulls Thwart Brief Sell-Off 3 Key Metrics Suggest Bitcoin Price Has Completed Its Macro Bear Cycle Bitcoin Subreddit Passes 1,200,000 Subscriber Milestone Bitcoin Price Drops to $7,200, but It Might Surge to $7,800 Sooner Than You Think Bullish Bitcoin Chart Pattern Still Intact Despite 7% Price Drop Data Scientist Uses Deep Learning to Predict BTC Price in Real-Time ‘Hodlers Are Insane’ — 64% of Bitcoin Supply Has Not Moved Since 2018 How the Upcoming Bitcoin Halving Compares to Previous Cycles Guy Who ‘Lost’ 4 BTC on Lightning Network Has Recovered Most Funds'

# %%
## Import library to check accuracy
from sklearn.metrics import classification_report, confusion_matrix, accuracy_score

# %%
matrix = confusion_matrix(test['label'], predictions)
print(matrix)

score = accuracy_score(test['label'], predictions)
print(score)

report = classification_report(test['label'], predictions)
print(report)
# Out:
# [[ 1 57]
#  [ 1 48]]
# 0.45794392523364486
#               precision    recall  f1-score   support
#
#            0       0.50      0.02      0.03        58
#            1       0.46      0.98      0.62        49
#
#     accuracy                           0.46       107
#    macro avg       0.48      0.50      0.33       107
# weighted avg       0.48      0.46      0.30       107
